# %% [markdown]
# 项目需求：开发一个多功能智能助手，支持：
# - 1. 天气查询：查询城市天气
# - 2. 数学计算：复杂数学运算
# - 3. 时间查询：获取当前时间、日期计算
# - 4. 货币转换：多种货币之间转换
# - 5. 信息搜索：搜索产品、新闻等信息

# %%
from langchain.chat_models import init_chat_model
from langchain.tools import tool
from langchain.agents import create_agent
from dotenv import load_dotenv
from datetime import datetime, timedelta
import os
import time
import math

# 1. 优先加载配置
load_dotenv(override=True)

# 2. 初始化大模型的配置
model_openai = init_chat_model(
    model="qwen3.7-flash",
    model_provider="openai",
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url=os.getenv("DASHSCOPE_BASE_URL"),
)

# 3. 定义工具
@tool
def get_weather(city: str) -> str:
    """获取指定城市的实时天气信息

    支持中国主要城市的天气查询

    Args:
        city: 城市名称，如北京、上海、深圳等

    Returns:
        包含温度、天气状况、空气质量的详细信息
    """
    weather_db = {
        "北京": "多云，15-22℃，空气质量良，湿度 45%",
        "上海": "晴天，18-25℃，空气质量优，湿度 60%",
        "深圳": "小雨，22-28℃，空气质量优，湿度 75%",
        "成都": "阴天，16-23℃，空气质量良，湿度 70%",
        "杭州": "晴天，17-24℃，空气质量优，湿度 55%",
        "广州": "多云，21-29℃，空气质量良，湿度 72%"
    }
    result = weather_db.get(city)
    if result:
        return f"{city}: {result}"
    else:
        return f"抱歉，暂不支持查询{city}的天气信息。当前支持城市：北京、上海、深圳、成都、杭州、广州"

@tool
def calculator(expression: str) -> str:
    """执行数学计算

    支持基本运算符(+、-、*、/、**)和常用的数学函数

    Args:
        expression: 数学表达式，可以包含：
            - 基本运算：2 + 3, 10 * 5, 100 / 4
            - 幂运算：2 ** 10
            - 函数：sqrt(16), abs(-5), pow(2, 3)

    Returns:
        计算结果或错误信息

    """
    try:
        # 安全的数学运算环境
        safe_functions = {
            "sqrt": math.sqrt,
            "pow": pow,
            "abs": abs,
            "round": round,
            "sin": math.sin,
            "cos": math.cos,
            "tan": math.tan,
            "log": math.log,
            "pi": math.pi,
            "e": math.e,
        }
        result = eval(expression, {"__builtins__": {}}, safe_functions)
        return f"{expression} = {result}"
    except Exception as e:
        return f"计算出错：{str(e)}\n提示：请检查表达式格式，支持的函数有 sqrt, abs, pow, round, sin, cos, tan, log"

@tool
def get_time_info(query_type: str = "current") -> str:
    """获取时间相关信息

    Args:
        query_type (str): 查询类型，支持以下值：
            - "current": 当前时间
            - "date": 今天日期
            - "tomorrow": 明天日期
            - "yesterday": 昨天日期
            - "weekday": 星期几

    Returns:
        str:时间信息字符串

    Examples:
        >>> get_time_info("current")
        '当前时间：2026年09月22日 14:30:25'
        >>> get_time_info("weekday")
        '今天是星期二'
    """
    now = datetime.now()
    if query_type == "current":
        return now.strftime("当前时间：%Y年%m月%d日 %H:%M:%S")
    elif query_type == "date":
        return now.strftime("今天式：%Y年%m月%d日")
    elif query_type == "tomorrow":
        tomorrow = now + timedelta(days=1)
        return tomorrow.strftime("明天式：%Y年%m月%d日")
    elif query_type == "yesterday":
        yesterday = now - timedelta(days=1)
        return yesterday.strftime("昨天式：%Y年%m月%d日")
    elif query_type == "weekday":  # 注意：原代码中elif判断的是"week"，但文档写的是"weekday"，这里建议统一
        weekdays = ["星期一", "星期二", "星期三", "星期四", "星期五", "星期六", "星期日"]
        return f"今天是{weekdays[now.weekday()]}"
    else:
        return f"不支持的查询类型：{query_type}。支持：current, date, tomorrow, yesterday, weekday"

@tool
def convert_currency(amount: float, from_curr: str, to_curr: str) -> str:
    """货币转换工具
    支持主要货币之间的实时汇率转换
    Args:
        amount: 金额数值
        from_curr: 源货币代码（CNY/USD/EUR/GBP/JPY/HKD）
        to_curr: 目标货币代码（CNY/USD/EUR/GBP/JPY/HKD）
    Returns:
        转换结果

    Examples:
        convert_currency(100, "CNY", "USD") 返回 "100 CNY = 14.00 USD"
    """
    exchange_rates = {
        "CNY": 1.0, # 人民币
        "USD": 0.14, # 美元
        "EUR": 0.13, # 欧元
        "GBP": 0.11, # 英镑
        "JPY": 20.8, # 日元
        "HKD": 1.09 # 港币
    }

    # 货币名称
    currency_names = {
    "CNY": "人民币", "USD": "美元", "EUR": "欧元",
    "GBP": "英镑", "JPY": "日元", "HKD": "港币"
    }

    from_curr = from_curr.upper()
    to_curr = to_curr.upper()

    if from_curr not in exchange_rates:
        return f"不支持的源货币：{from_curr}。支持的货币：CNY, USD, EUR, GBP,JPY, HKD"
    if to_curr not in exchange_rates:
        return f"不支持的目标货币：{to_curr}。支持的货币：CNY, USD, EUR, GBP,JPY, HKD"

    # 转换逻辑：先转为 CNY，再转为目标货币
    cny_amount = amount / exchange_rates[from_curr]
    result_amount = cny_amount * exchange_rates[to_curr]

    from_name = currency_names[from_curr]
    to_name = currency_names[to_curr]

    return f"{amount} {from_name}（{from_curr}）= {result_amount:.2f} {to_name}（{to_curr}）"

@tool
def search_info(keyword: str, category: str = "all") -> str:
    """搜索各类信息

    Args:
        keyword: 搜索关键词
        category: 搜索分类
            - "product": 搜索产品
            - "news": 搜索新闻
            - "all": 搜索所有

    Returns:
        搜索结果
    """
    # 模拟数据库
    products = {
        "手机": "iPhone 15 (¥5999), 小米14 (¥3999), 华为Mate60 (¥6999)",
        "笔记本": "MacBook Pro (¥12999), ThinkPad X1 (¥9999), 华为MateBook(¥7999)",
        "耳机": "AirPods Pro (¥1999), Sony WH-1000XM5 (¥2499)"
    }

    news = {
        "AI": "1. GPT-5 即将发布 2. AI 芯片市场增长 30% 3. 新AI法规出台",
        "科技": "1. 量子计算新突破 2. 6G 技术测试 3. 新能源汽车销量创新高"
    }

    results = []

    if category in ["product", "all"]:
        for key, value in products.items():
            if keyword in key:
                results.append(f"【产品】{key}: {value}")

    if category in ["news", "all"]:
        for key, value in news.items():
            if keyword in key or keyword in value:
                results.append(f"【新闻】{key}相关: {value}")
    if results:
        return "\n".join(results)
    else:
        return f"未找到关于 '{keyword}'的{category}"

# 4. 创建一个智能体类
class SmartAssistant:
    """多功能只能助手"""
    def __init__(self):
        #初始化模型
        self.model = model_openai

        #工具列表
        self.tools = [
            get_weather,
            calculator,
            get_time_info,
            convert_currency,
            search_info,
        ]

        # 系统提示词
        custom_system_prompt = """你是一个多功能智能助手，可以帮助用户：
        🌤 查询天气：使用 get_weather 工具
        🔢 数学计算：使用 calculator 工具
        ⏰ 时间查询：使用 get_time_info 工具
        💱 货币转换：使用 convert_currency 工具
        🔍 信息搜索：使用 search_info 工具
        重要提示：
        1. 仔细阅读用户问题，确定需要使用哪个工具
        2. 如果需要多个工具，按顺序调用
        3. 总是用友好、专业的语气回答
        4. 如果工具返回了数据，要用通俗易懂的语言解释给用户
        5. 如果无法完成任务，诚实地告诉用户原因
        请始终使用中文回答。"""

        # ✅ 创建 agent
        self.agent = create_agent(
            model=self.model,
            tools=self.tools,
            system_prompt=custom_system_prompt,
        )

        # 对话历史
        self.messages = []

    def chat(self, user_input: str) -> str:
        """对话接口"""
        #添加用户消息
        self.messages.append({"role": "user", "content": user_input})

        # 调用agent
        result = self.agent.invoke({"messages": self.messages})

        #更新消息历史
        self.messages = result["messages"]

        # 返回最后一条AI 消息
        for msg in reversed(self.messages):
            if msg.type == "ai" and msg.content:
                return msg.content

        return "抱歉，我无法处理这个请求。"

    def reset(self):
        """重置对话历史"""
        self.messages = []

# =================================== 主程序 ===============================
def main():
    assistant = SmartAssistant()

    print("=" * 66)
    print("🤖 多功能智能助手（LangChain 1.3.18）")
    print("=" * 40)
    print("\n我可以帮你：")
    print(" 🌤 查询天气")
    print(" 🔢 数学计算")
    print(" ⏰ 时间查询")
    print(" 💱 货币转换")
    print(" 🔍 信息搜索")
    print("\n输入 'quit' 退出，输入 'reset' 重置对话\n")

    demos = [
        "北京今天天气怎么样？",
        "帮我算一下 (25 + 17) * 3",
        "现在几点了？",
        "100 美元等于多少人民币？"
    ]

    for demo in demos:
        print(f"👤 {demo}")
        response = assistant.chat(demo)
        print(f"🤖 {response}\n")

    # 重置对话
    assistant.reset()

    # 交互模式
    print("=" * 40)
    print("💬 进入交互模式")
    print("=" * 40)

    while True:
        user_input = input("\n👤 你: ")
        if user_input.lower() == 'quit':
            print("再见！👋")
            break
        if user_input.lower() == 'reset':
            assistant.reset()
            print("✅ 对话已重置")
            continue
        if not user_input.strip():
            continue

        # 调用助手
        response = assistant.chat(user_input)
        print(f"🤖 助手: {response}")

if __name__ == "__main__":
    main()
# Out:
# ==================================================================
# 🤖 多功能智能助手（LangChain 1.3.18）
# ========================================
#
# 我可以帮你：
#  🌤 查询天气
#  🔢 数学计算
#  ⏰ 时间查询
#  💱 货币转换
#  🔍 信息搜索
#
# 输入 'quit' 退出，输入 'reset' 重置对话
#
# 👤 北京今天天气怎么样？
# 🤖 北京今天的天气是多云，气温在15℃到22℃之间。空气质量状况良好，湿度为45%。这是一个比较适合外出的天气呢！如果您计划出门，可以带一件薄外套以防早晚温差。
#
# 👤 帮我算一下 (25 + 17) * 3
# 🤖 这个算式的结果是：
# (25 + 17) * 3 = **126**
#
# 如果您还有其他数学问题，随时告诉我哦！ 😊
#
# 👤 现在几点了？
# 🤖 现在是 **21点27分**（晚上九点半左右）。
# 如果您需要其他时间相关的帮助，随时可以问我哦！ 🌙
#
# 👤 100 美元等于多少人民币？
# 🤖 100 美元（USD）等于 **714.29 人民币（CNY）**。
# 请注意，汇率会实时变动，所以实际交易时请以银行或金融机构的最新汇率为准哦！ 😊
#
# ========================================
# 💬 进入交互模式
# ========================================
# 🤖 助手: 深圳今天的天气情况如下：
#
# 🌧️ **天气状况**：小雨
# 🌡️ **温度范围**：22-28℃
# 💨 **空气质量**：优
# 💧 **湿度**：75%
#
# 温馨提示：由于今天有小雨，出门建议携带雨伞，注意防雨哦！
# 🤖 助手: 深圳今天的天气情况如下：
#
# 🌧️ **天气状况**：小雨
# 🌡️ **温度范围**：22-28℃
# 💨 **空气质量**：优
# 💧 **湿度**：75%
#
# 温馨提示：由于今天有小雨且湿度较大，出门建议您随身携带雨伞，并注意添衣保暖。
# 🤖 助手: (37 + 13) * 3 的计算结果是 **150**。
#
# 计算步骤如下：
# 1. 先算括号里的加法：37 + 13 = 50
# 2. 再算乘法：50 * 3 = 150
# 🤖 助手: 现在的时间是 2026 年 09 月 22 日 21:31:02。
# 🤖 助手: 100 美元（USD）目前大约等于 **714.29** 人民币（CNY）。
#
# 请注意，汇率会随市场波动实时变化，以上数据仅供参考。
# 🤖 助手: 为您查询到的最新 AI 相关新闻如下：
#
# 1. **GPT-5 即将发布**：备受瞩目的 GPT-5 预计将在近期面世，引发了各界的广泛关注。
# 2. **AI 芯片市场增长 30%**：随着人工智能应用的普及，AI 芯片市场需求强劲，市场规模实现了 30% 的增长。
# 3. **新 AI 法规出台**：为了规范人工智能技术的发展和应用，新的监管法规已经正式发布实施。
#
# 希望这些信息对您有帮助！如果您想了解某个新闻的详细内容，可以告诉我。
# 再见！👋
