# %% [markdown]
# ## 工具的定义方式1：不使用@tool
#
# ### 模型绑定工具并发请求

# %%
from langchain.chat_models import init_chat_model
from rich import print as rprint
from dotenv import load_dotenv
from langchain_core.utils.function_calling import convert_to_openai_tool
import os

load_dotenv(override=True)

model_openai = init_chat_model(
    model="qwen3.7-flash",
    model_provider="openai",
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url=os.getenv("DASHSCOPE_BASE_URL"),
)
# 函数参数设置默认值 深圳，并且给出为str类型
def get_weather(city: str = '深圳') -> str:
    """
    查询地方的天气

    Args:
        city: 城市名称

    Returns:
        返回当前城市的天气情况
    """
    return f"{city}天气晴朗，适合郊游"

#模型绑定后返回消息
tool_messages = model_openai.bind_tools([get_weather])

result = tool_messages.invoke(
    "今天北京的天气如何"
)

rprint(result)
print("*" * 50)
#查看参数
rprint(convert_to_openai_tool(get_weather))
# Out:
# AIMessage(
#     content='',
#     additional_kwargs={'refusal': None},
#     response_metadata={
#         'token_usage': {
#             'completion_tokens': 280,
#             'prompt_tokens': 276,
#             'total_tokens': 556,
#             'completion_tokens_details': {
#                 'accepted_prediction_tokens': None,
#                 'audio_tokens': None,
#                 'reasoning_tokens': 252,
#                 'rejected_prediction_tokens': None,
#                 'text_tokens': 280
#             },
#             'prompt_tokens_details': {
#                 'audio_tokens': None,
#                 'cache_write_tokens': None,
#                 'cached_tokens': 0,
#                 'text_tokens': 276
#             }
#         },
#         'model_provider': 'openai',
#         'model_name': 'qwen3.7-flash',
#         'system_fingerprint': None,
#         'id': 'chatcmpl-ff6ce9c1-6558-9369-ac31-32bb03e46d66',
#         'finish_reason': 'tool_calls',
#         'logprobs': None
#     },
#     id='lc_run--01a0a989-91a4-7c13-8e95-3ac9e3fec8e5-0',
#     tool_calls=[
#         {
#             'name': 'get_weather',
#             'args': {'city': '北京'},
#             'id': 'call_0f124cb5936d4665bc9f368f',
#             'type': 'tool_call'
#         }
#     ],
#     invalid_tool_calls=[],
#     usage_metadata={
#         'input_tokens': 276,
#         'output_tokens': 280,
#         'total_tokens': 556,
#         'input_token_details': {'cache_read': 0},
#         'output_token_details': {'reasoning': 252}
#     }
# )
# **************************************************
# {
#     'type': 'function',
#     'function': {
#         'name': 'get_weather',
#         'description': '查询地方的天气',
#         'parameters': {
#             'properties': {'city': {'default': '深圳', 'description': '城市名称', 'type': 'string'}},
#             'type': 'object'
#         }
#     }
# }
