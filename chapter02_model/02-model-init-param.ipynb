# %% [markdown]
# # 模型初始化的参数使用情况
#
# ## 1. temperature的使用
# 控制输出随机性，范围 0.0-2.0，温度越高输出越随机。
# - 0.0 ：最确定性，输出几乎不变
# - 1.0 ：平衡创造性和一致性
# - 2.0 ：最随机，最有创造性
#
# 其中的使用场景如下：
# - 0.0-0.3：需要一致性、准确性的任务（数学计算、数据提取、分类、代码生成）
# - 0.5-0.7：平衡创造性和一致性（聊天、问答）
# - 0.8-1.5：创造性任务（写作、头脑风暴）
# - 1.5-2.0：高度创造性（诗歌、故事创作）

# %%
import os

from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv(verbose=True)

DEEPSEEK_API_KEY = os.getenv('DEEPSEEK_API_KEY')
DEEPSEEK_BASE_URL = os.getenv('DEEPSEEK_BASE_URL')

llm_model = init_chat_model(
    model='deepseek-flash',
    model_provider='deepseek',
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=2,
)

for i in range(3):
    print(llm_model.invoke('帮我写一首描述春天的七言绝句诗').content)
# Out:
# 《七绝·春景》
# 春色满园映日红，
# 柳丝轻拂绿波中。
# 莺啼燕语传佳韵，
# 蝶舞蜂飞醉暖风。
#
# 赏析：这首作品以“春色满园”起笔，通过“映日红”生动描绘了春日繁花似锦的盛景。后三句巧妙运用柳丝、莺燕、蝶蜂等典型春意象，以“轻拂”“传佳韵”“醉暖风”等拟人化手法，赋予自然景物灵动的生命力，共同勾勒出一幅声色俱佳、动静相宜的春景图，充分传达出对春天的沉醉与赞美之情。
# 《七绝·春景》
# 吹面不寒杨柳风，花开满树映山红。
# 翩翩彩蝶丛中舞，入耳莺啼绿映中。
#
# 赏析：这首作品以春风、花树、彩蝶、莺啼等意象勾勒出生机盎然的春景图。首句“吹面不寒杨柳风”化用古诗句，巧妙传达春风的温柔；次句“花开满树映山红”色彩明丽，展现春日的绚烂；后两句通过蝶舞莺啼的动态描写，赋予画面灵动之感，尾句“绿映中”更以色彩收束，强化视觉美感。
# 《七绝·春景》
# 东君送暖入屠苏，次第繁花映野芜。
# 莺燕争啼深树里，一犁膏雨润如酥。
#
# 注：我的创作思路是围绕“春”的主题，通过典型的春日意象来勾勒生机盎然的画面。首句“东君送暖”点明时令，次句“繁花映野”展现视觉之美。后两句转入听觉与触觉，莺啼燕语与润物细雨交织，形成多感官的春日交响，末句“润如酥”化用韩愈诗意，暗含对丰收的期许。
